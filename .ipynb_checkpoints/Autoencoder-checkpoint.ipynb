# %% [markdown]
# # Importing the necessary libraries

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
# Out:
# 2023-08-25 11:05:14.765263: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-25 11:05:14.816968: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-25 11:05:14.817654: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-25 11:05:15.693021: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras import layers, losses

# %%
from tensorflow.keras.models import Model

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from tensorflow.keras.models import load_model

# %%
from tensorflow.keras.models import save_model

# %% [markdown]
# # Importing the data

# %%
train_data_set = pd.read_csv("train_data.txt",index_col = None)

# %%
train_data_set.head()
# Out:
#   Unnamed: 0    x1   x2   x3   x4       y0      y1      y2       y3      y4  \
# 0     model1  0.75  125  395  120   7.7722  203.89  13.258  169.906  3.7122
# 1     model2  0.75  125  385   90   7.5517  201.38  11.350  201.379  3.6934
# 2     model3  0.50  135  395   90   7.9131  167.20  10.688  167.202  3.6899
# 3     model4  0.25  150  395  120   9.0806  217.86  15.444  181.551  3.7313
# 4     model5  0.25  165  395   90  10.0079  179.26  12.038  179.259  3.7012
#
#    ...     y92     y93     y94     y95     y96     y97     y98     y99  \
# 0  ...  4.3853  0.0013  0.0073  0.0059  0.0069  0.0073  0.0043  0.0050
# 1  ...  4.3800  0.0013  0.0076  0.0068  0.0071  0.0075  0.0042  0.0044
# 2  ...  4.3747  0.0011  0.0090  0.0073  0.0091  0.0088  0.0028  0.0025
# 3  ...  4.3785  0.0008  0.0076  0.0046  0.0069  0.0066  0.0024  0.0028
# 4  ...  4.3702  0.0008  0.0080  0.0058  0.0077  0.0072  0.0025  0.0021
#
#      y100    y101
# 0  0.0052  0.0051
# 1  0.0046  0.0044
# 2  0.0033  0.0029
# ...

# %% [markdown]
# # Dropping the first column

# %%
train_data_set.drop(columns=train_data_set.columns[0], axis=1, inplace=True)

# %%
train_data_set = train_data_set.to_numpy()

# %%
train_data_set_original = train_data_set.astype(np.float32)

# %%
train_data_set = train_data_set.astype(np.float32)

# %% [markdown]
# # Normalizing the dataset

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train_data_set)
# Out:
# MinMaxScaler()

# %%
train_data_set = scaler.transform(train_data_set)

# %% [markdown]
# # Doing a train-test split

# %%
train_data_set, test_data_set = train_test_split(train_data_set,test_size=10,train_size=90,shuffle=True)

# %% [markdown]
# # Separating the Input features (x) and Output features (y)

# %%
train_data_set_x = train_data_set[:,0:4]

# %%
train_data_set_y = train_data_set[:,4:]

# %%
test_data_set_x = test_data_set[:,0:4]

# %%
test_data_set_y = test_data_set[:,4:]

# %%
train_data_set.shape
# Out:
# (90, 106)

# %%
test_data_set_x.shape
# Out:
# (10, 4)

# %% [markdown]
# # Defining an autoencoder

# %%
class Autoencoder(Model):
    def __init__(self, latent_dim, shape):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.shape = shape
        self.encoder = tf.keras.Sequential([
            layers.Flatten(),
            layers.Dense(102,activation='relu'),
            layers.Dense(40,activation='relu'),
            layers.Dense(15,activation='relu'),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = tf.keras.Sequential([
            layers.Dense(latent_dim,activation='relu'),
            layers.Dense(15,activation='relu'),
            layers.Dense(40,activation='relu'),
            layers.Dense(102, activation='relu'),
            layers.Reshape(shape)
        ])
    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
shape = (train_data_set_y.shape[1],1)

# %% [markdown]
# # Bottle-neck

# %%
latent_dim = 10

# %% [markdown]
# # Creating an instance of Autoencoder

# %%
autoencoder = Autoencoder(latent_dim, shape)

# %% [markdown]
# # Compiling autoencoder

# %%
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

# %% [markdown]
# # Training autoencoder

# %%
autoencoder.fit(train_data_set_y, train_data_set_y,epochs=10000,shuffle=True,validation_split=0.3)
# Out:
# Epoch 1/10000
# 2/2 [==============================] - 2s 296ms/step - loss: 0.2995 - val_loss: 0.2724
# Epoch 2/10000
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2810 - val_loss: 0.2521
# Epoch 3/10000
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2587 - val_loss: 0.2291
# Epoch 4/10000
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2345 - val_loss: 0.2062
# Epoch 5/10000
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2109 - val_loss: 0.1908
# Epoch 6/10000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1979 - val_loss: 0.1893
# Epoch 7/10000
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1980 - val_loss: 0.1898
# Epoch 8/10000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1956 - val_loss: 0.1816
# Epoch 9/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1861 - val_loss: 0.1720
# Epoch 10/10000
# ...

# %% [markdown]
# # Encoding the output features

# %%
encoded_data = autoencoder.encoder(train_data_set_y).numpy()

# %% [markdown]
# # Decoding the encoded output features

# %%
decoded_data = autoencoder.decoder(encoded_data).numpy()

# %%
decoded_data.shape[:-1]
# Out:
# (90, 102)

# %%
decoded_data = decoded_data.reshape(decoded_data.shape[:-1])

# %%
num_features = train_data_set_y.shape[1]

# %%
Errors = np.zeros(num_features)

# %%
for feature in range(num_features):
    a = train_data_set_y[:,feature]
    b = decoded_data[:,feature]
    Errors[feature] = np.linalg.norm((a-b)/90)

# %%
plt.bar(np.arange(num_features),Errors)
plt.title("Error in the Autoencoder")
plt.xlabel("Features")
plt.ylabel("Error")
plt.grid()
plt.show()

# %%
feature = 61

# %%
plt.plot(train_data_set_y[:,feature],label = "Original")
plt.plot(decoded_data[:,feature],label = "Predicted")
plt.legend()
plt.show()

# %% [markdown]
# # Linear Network

# %%
class Linear_Network(Model):
    def __init__(self, latent_dim, shape):
        super(Linear_Network, self).__init__()
        self.latent_dim = latent_dim
        self.shape = shape

        self.Layers = tf.keras.Sequential([
          layers.Dense(6,activation='relu'),
          layers.Dense(8,activation='relu'),
          layers.Dense(8,activation='relu'),
          layers.Dense(latent_dim, activation='relu'),
        ])
    def call(self, x):
        output = self.Layers(x)
        return output

# %%
linear_network = Linear_Network(latent_dim, shape)

# %% [markdown]
# # Compiling

# %%
linear_network.compile(optimizer='adam', loss=losses.MeanSquaredError())

# %% [markdown]
# # Training

# %%
linear_network.fit(train_data_set_x, encoded_data,
                epochs=10000,
                shuffle=True,
               validation_split=0.3)
# Out:
# Epoch 1/10000
# 2/2 [==============================] - 1s 118ms/step - loss: 5.4735 - val_loss: 5.3714
# Epoch 2/10000
# 2/2 [==============================] - 0s 35ms/step - loss: 5.4631 - val_loss: 5.3606
# Epoch 3/10000
# 2/2 [==============================] - 0s 48ms/step - loss: 5.4524 - val_loss: 5.3490
# Epoch 4/10000
# 2/2 [==============================] - 0s 45ms/step - loss: 5.4402 - val_loss: 5.3366
# Epoch 5/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 5.4277 - val_loss: 5.3235
# Epoch 6/10000
# 2/2 [==============================] - 0s 40ms/step - loss: 5.4142 - val_loss: 5.3095
# Epoch 7/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 5.4000 - val_loss: 5.2949
# Epoch 8/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 5.3851 - val_loss: 5.2796
# Epoch 9/10000
# 2/2 [==============================] - 0s 39ms/step - loss: 5.3694 - val_loss: 5.2635
# Epoch 10/10000
# ...

# %%
test_data_set_x = test_data_set[:,0:4]
latent_data = linear_network.Layers(train_data_set_x)

# %%
output = autoencoder.decoder(latent_data).numpy()

# %%
output = output.reshape(output.shape[:-1])

# %%
feature = 7

# %%
plt.plot(train_data_set_y[:,feature],label = "Original")
plt.plot(output[:,feature],label = "Predicted")
plt.title("Error in the Linear Network")
plt.xlabel("Features")
plt.ylabel("Error")
plt.legend()
plt.show()

# %%
num_features = train_data_set_y.shape[1]

# %%
Errors = np.zeros(num_features)

# %%
for feature in range(num_features):
    a = train_data_set_y[:,feature]
    b = output[:,feature]
    Errors[feature] = np.linalg.norm((a-b)/90)

# %%
plt.bar(np.arange(num_features),Errors)
plt.grid()
plt.show()

# %%
Error_Tolerance = .02

# %%
Large_Deviation = []

# %%
for i,error in enumerate(Errors):
    if error > Error_Tolerance:
        Large_Deviation.append(i)
        print(f"Index: {i}, Error: {error}")
# Out:
# Index: 17, Error: 0.05534084141254425
# Index: 24, Error: 0.05928882956504822
# Index: 28, Error: 0.05471593141555786
# Index: 32, Error: 0.05921650677919388
# Index: 52, Error: 0.05963943153619766
# Index: 57, Error: 0.058752454817295074
# Index: 90, Error: 0.05272657796740532

# %%
latent_test_data = linear_network.Layers(test_data_set_x)

# %%
output_test_data = autoencoder.decoder(latent_test_data).numpy()

# %%
output_test_data = output_test_data.reshape(output_test_data.shape[:-1])

# %%
test_data_set_x = test_data_set[:,0:4]
Errors_test_data = np.zeros(num_features)

# %%
for feature in range(num_features):
    a = test_data_set_y[:,feature]
    b = output_test_data[:,feature]
    Errors_test_data[feature] = np.linalg.norm((a-b)/10)

# %%
plt.bar(np.arange(num_features),Errors_test_data)
plt.grid()
plt.show()

# %%
Error_Tolerance = .04

# %%
for i,error in enumerate(Errors_test_data):
    if error > Error_Tolerance:
        print(f"Index: {i}, Error: {error}")
# Out:
# Index: 17, Error: 0.17194852232933044
# Index: 24, Error: 0.17105410993099213
# Index: 28, Error: 0.1527392566204071
# Index: 32, Error: 0.17249178886413574
# Index: 52, Error: 0.17332270741462708
# Index: 57, Error: 0.16852296888828278
# Index: 78, Error: 0.04057515040040016
# Index: 80, Error: 0.04117854684591293
# Index: 82, Error: 0.042049530893564224
# Index: 90, Error: 0.1416747272014618

# %% [markdown]
# # Features NOT captured

# %%
Large_Deviation
# Out:
# [17, 24, 28, 32, 52, 57, 90]

# %%
Large_Deviation_Dataset = train_data_set_y[:,Large_Deviation]

# %%
num_l_deviation = Large_Deviation_Dataset.shape[1]

# %% [markdown]
# # To capture the uncaptured features

# %%
class Linear_Network_Large_Deviation(Model):
    def __init__(self, latent_dim, shape):
        super(Linear_Network_Large_Deviation, self).__init__()
        self.latent_dim = latent_dim
        self.shape = shape

        self.Layers = tf.keras.Sequential([
          layers.Dense(latent_dim,activation='relu'),
          layers.Dense(latent_dim+4,activation='relu'),
          layers.Dense(latent_dim, activation='relu'),
          # layers.Dense(tf.math.reduce_prod(shape), activation='relu'),
          # layers.Dense(latent_dim, activation='relu'),
          # layers.Reshape(shape)
        ])

    def call(self, x):
        output = self.Layers(x)
        return output

# %%
linear_network_large_deviation = Linear_Network_Large_Deviation(num_l_deviation,(num_l_deviation,1))

# %% [markdown]
# # Compiling

# %%
linear_network_large_deviation.compile(optimizer='adam', loss=losses.MeanSquaredError())

# %% [markdown]
# # Training

# %%
linear_network_large_deviation.fit(train_data_set_x, Large_Deviation_Dataset,
                epochs=5000,
                shuffle=True,
               validation_split=0.3)
# Out:
# Epoch 1/5000
# 2/2 [==============================] - 1s 113ms/step - loss: 0.1966 - val_loss: 0.1933
# Epoch 2/5000
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1899 - val_loss: 0.1870
# Epoch 3/5000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1836 - val_loss: 0.1807
# Epoch 4/5000
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1773 - val_loss: 0.1745
# Epoch 5/5000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1708 - val_loss: 0.1684
# Epoch 6/5000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1643 - val_loss: 0.1623
# Epoch 7/5000
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1581 - val_loss: 0.1563
# Epoch 8/5000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1520 - val_loss: 0.1506
# Epoch 9/5000
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1461 - val_loss: 0.1454
# Epoch 10/5000
# ...

# %%
output_l_data = linear_network_large_deviation.Layers(train_data_set_x)

# %%
Errors_test_data_l = np.zeros(num_l_deviation)

# %%
for feature in range(num_l_deviation):
    a = Large_Deviation_Dataset[:,feature]
    b = output_l_data[:,feature]
    Errors_test_data_l[feature] = np.linalg.norm((a-b)/90)

# %%
plt.bar(np.arange(num_l_deviation),Errors_test_data_l)
plt.title("Error in the Large Deviation Network: Train Data")
plt.xlabel("Features")
plt.ylabel("Error")
plt.grid()
plt.show()

# %%
output_l_data = linear_network_large_deviation.Layers(test_data_set_x)

# %%
Errors_test_data_l = np.zeros(num_l_deviation)

# %%
Large_Deviation_Dataset = test_data_set_y[:,Large_Deviation]

# %%
for feature in range(num_l_deviation):
    a = Large_Deviation_Dataset[:,feature]
    b = output_l_data[:,feature]
    Errors_test_data_l[feature] = np.linalg.norm((a-b)/10)

# %%
plt.bar(np.arange(num_l_deviation),Errors_test_data_l)
plt.title("Error in the Large Deviation Network: Test Data")
plt.xlabel("Features")
plt.ylabel("Error")
plt.grid()
plt.show()

# %%
test_data_set_y
# Out:
# array([[0.87699056, 0.41227806, 0.6754737 , ..., 0.16216215, 0.02941179,
#         0.02857143],
#        [0.8025043 , 0.41227806, 0.37496698, ..., 0.02702701, 0.02941179,
#         0.02857143],
#        [0.37370467, 0.68455315, 0.37074375, ..., 0.08108112, 0.14705884,
#         0.14285713],
#        ...,
#        [0.17428493, 0.6705451 , 0.82922447, ..., 0.5675676 , 0.58823526,
#         0.5428571 ],
#        [0.4296286 , 0.42689848, 0.37338328, ..., 0.02702701, 0.11764705,
#         0.11428571],
#        [0.90407944, 0.4384569 , 0.5473261 , ..., 0.24324325, 0.17647064,
#         0.14285713]], dtype=float32)

# %%
test_data_set_y[1,:].shape
# Out:
# (102,)

# %%
output_test_data
# Out:
# array([[0.83786225, 0.4965256 , 0.6755858 , ..., 0.17263216, 0.        ,
#         0.00098345],
#        [0.7851939 , 0.37898487, 0.3759688 , ..., 0.04591266, 0.07080656,
#         0.04191417],
#        [0.43320054, 0.61893   , 0.40688613, ..., 0.06589831, 0.13907155,
#         0.10601193],
#        ...,
#        [0.10378163, 0.60242856, 0.81792665, ..., 0.49471238, 0.5185915 ,
#         0.5010269 ],
#        [0.44300175, 0.44428352, 0.33535284, ..., 0.06448133, 0.15482098,
#         0.12276667],
#        [0.7312533 , 0.509493  , 0.57664084, ..., 0.35268524, 0.26474056,
#         0.2238358 ]], dtype=float32)

# %% [markdown]
# # Combinig the outputs

# %%
for i,index in enumerate(Large_Deviation):
    print(index)
    output_test_data[:,index] = output_l_data[:,i]
# Out:
# 17
# 24
# 28
# 32
# 52
# 57
# 90

# %%
Data_after_processing = np.zeros((100,106))

# %%
temp = np.concatenate((test_data_set_x,output_test_data),axis = 1)

# %%
temp.shape
# Out:
# (10, 106)

# %% [markdown]
# # Transform the data to original feature space

# %%
Data_Predicted_original_domain = scaler.inverse_transform(temp)

# %% [markdown]
# # Saving the models

# %%
save_model(autoencoder, "autoencoder_v1.tf")
# Out:
# INFO:tensorflow:Assets written to: autoencoder_v1.tf/assets
# INFO:tensorflow:Assets written to: autoencoder_v1.tf/assets

# %%
save_model(linear_network_large_deviation, "linear_l_network_v1.tf")
# Out:
# INFO:tensorflow:Assets written to: linear_l_network_v1.tf/assets
# INFO:tensorflow:Assets written to: linear_l_network_v1.tf/assets

# %%
save_model(linear_network, "linear_network_v1.tf")
# Out:
# INFO:tensorflow:Assets written to: linear_network_v1.tf/assets
# INFO:tensorflow:Assets written to: linear_network_v1.tf/assets

# %%
model = load_model('autoencoder_v1.tf')

# %%
Result_data_set = pd.read_csv("test_data.txt",index_col = None)

# %%
Result_data_set.drop(columns=Result_data_set.columns[0], axis=1, inplace=True)

# %%
Result_data_set = Result_data_set.to_numpy()

# %%
Result_data_set_original = Result_data_set.astype(np.float32)

# %%
Result_data_set = Result_data_set.astype(np.float32)

# %%
Result_data_set.shape
# Out:
# (40, 4)

# %%
temp = np.zeros((40,102))

# %%
Result_data_set = np.concatenate((Result_data_set,temp),axis = 1)

# %%
Result_data_set = scaler.transform(Result_data_set)

# %%
Result_data_set.shape
# Out:
# (40, 106)

# %%
Result_data_set = Result_data_set[:,:4]

# %%
data = linear_network(Result_data_set)

# %%
data = autoencoder.decoder(data)

# %%
data = data.numpy()

# %%
data.reshape(data.shape[:-1])
# Out:
# array([[0.7251723 , 0.5686881 , 0.5742049 , ..., 0.10621918, 0.01239446,
#         0.        ],
#        [0.48277336, 0.31427515, 0.2565641 , ..., 0.18536562, 0.20497894,
#         0.13708061],
#        [0.1260088 , 0.49593705, 0.22108708, ..., 0.4333018 , 0.5330671 ,
#         0.4899531 ],
#        ...,
#        [0.24110192, 0.25943598, 0.541548  , ..., 0.07959939, 0.11671136,
#         0.08213666],
#        [0.2712031 , 0.4341131 , 0.35116193, ..., 0.05912859, 0.16534229,
#         0.1341852 ],
#        [0.20528351, 0.23782767, 0.45864403, ..., 0.2636255 , 0.38398442,
#         0.31502464]], dtype=float32)

# %%
Large_Deviation_data = linear_network_large_deviation(Result_data_set)

# %%
Large_Deviation_data = Large_Deviation_data.numpy()

# %%
Large_Deviation_data.shape
# Out:
# (40, 7)

# %%
for i,index in enumerate(Large_Deviation):
    print(index)
    data[:,index] = Large_Deviation_data[:,i].reshape(40,1)
# Out:
# 17
# 24
# 28
# 32
# 52
# 57
# 90

# %%
data = data.reshape(data.shape[:-1])

# %%
Result_data_set.shape
# Out:
# (40, 4)

# %%
sol_1 = np.concatenate((Result_data_set,data),axis = 1)

# %%
sol_1 = scaler.inverse_transform(sol_1)

# %%
sol_1
# Out:
# array([[3.00000012e-01, 1.62000000e+02, 3.76000000e+02, ...,
#         2.09301100e-03, 2.14214115e-03, 1.90000003e-03],
#        [5.40000021e-01, 1.53000000e+02, 3.82000000e+02, ...,
#         2.38585282e-03, 2.79692840e-03, 2.37978220e-03],
#        [6.00000024e-01, 1.34000000e+02, 3.78000000e+02, ...,
#         3.30321674e-03, 3.91242816e-03, 3.61483601e-03],
#        ...,
#        [2.80000001e-01, 1.32000000e+02, 3.93000000e+02, ...,
#         1.99451776e-03, 2.49681863e-03, 2.18747837e-03],
#        [2.50000000e-01, 1.42000000e+02, 3.87000000e+02, ...,
#         1.91877581e-03, 2.66216377e-03, 2.36964825e-03],
#        [4.30000007e-01, 1.25000000e+02, 3.92000000e+02, ...,
#         2.67541440e-03, 3.40554701e-03, 3.00258637e-03]])

# %%
pd_data = pd.DataFrame(data)

# %%
pd_data.to_csv("Result.csv",index_label=None)

# %%
sol = pd.read_csv("test_data.txt")

# %%
data[:,1].shape
# Out:
# (40,)

# %%
for i in range(num_features):
    string = "y"+str(i)
    print(string)
    sol[string] = sol_1[:,i+4]
# Out:
# y0
# y1
# y2
# y3
# y4
# y5
# y6
# y7
# y8
# y9
# y10
# y11
# y12
# y13
# y14
# y15
# y16
# y17
# y18
# y19
# y20
# y21
# y22
# y23
# y24
# y25
# y26
# y27
# y28
# y29
# y30
# y31
# y32
# y33
# y34
# y35
# y36
# y37
# y38
# y39
# y40
# y41
# y42
# y43
# y44
# y45
# y46
# y47
# y48
# y49
# y50
# y51
# y52
# y53
# y54
# y55
# y56
# y57
# y58
# y59
# y60
# y61
# y62
# y63
# y64
# y65
# y66
# y67
# y68
# y69
# y70
# y71
# y72
# y73
# y74
# y75
# y76
# y77
# y78
# y79
# y80
# y81
# y82
# y83
# y84
# y85
# y86
# y87
# y88
# y89
# y90
# y91
# y92
# y93
# y94
# y95
# y96
# y97
# y98
# y99
# y100
# y101
# /tmp/ipykernel_232000/2455058246.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sol[string] = sol_1[:,i+4]
# ...

# %%
sol.head()
# Out:
#   Unnamed: 0    x1     x2     x3    x4        y0          y1         y2  \
# 0     model1  0.30  162.0  376.0  93.0  9.494088  225.243402  12.981666
# 1     model2  0.54  153.0  382.0  86.0  8.675312  192.006895  10.574838
# 2     model3  0.60  134.0  378.0  81.0  7.470233  215.739206  10.306021
# 3     model4  0.46  159.0  388.0  87.0  9.153165  177.757130  10.303690
# 4     model5  0.51  144.0  389.0  88.0  8.363700  175.174413  10.040257
#
#            y3        y4  ...       y92       y93       y94       y95  \
# 0  204.497304  3.704213  ...  4.369438  0.000659  0.008169  0.005792
# 1  199.930673  3.686643  ...  4.370361  0.000931  0.008625  0.006859
# 2  218.291782  3.683531  ...  4.374809  0.001290  0.008743  0.007324
# 3  188.516168  3.685742  ...  4.368332  0.000845  0.008786  0.006791
# 4  180.164683  3.684135  ...  4.371345  0.001067  0.008992  0.007128
#
#         y96       y97       y98       y99      y100      y101
# ...

# %%
sol.columns[0]
# Out:
# 'Unnamed: 0'

# %%
sol.rename(columns={sol.columns[0]: ""}, inplace=True)

# %%
sol.head()
# Out:
#              x1     x2     x3    x4        y0          y1         y2  \
# 0  model1  0.30  162.0  376.0  93.0  9.494088  225.243402  12.981666
# 1  model2  0.54  153.0  382.0  86.0  8.675312  192.006895  10.574838
# 2  model3  0.60  134.0  378.0  81.0  7.470233  215.739206  10.306021
# 3  model4  0.46  159.0  388.0  87.0  9.153165  177.757130  10.303690
# 4  model5  0.51  144.0  389.0  88.0  8.363700  175.174413  10.040257
#
#            y3        y4  ...       y92       y93       y94       y95  \
# 0  204.497304  3.704213  ...  4.369438  0.000659  0.008169  0.005792
# 1  199.930673  3.686643  ...  4.370361  0.000931  0.008625  0.006859
# 2  218.291782  3.683531  ...  4.374809  0.001290  0.008743  0.007324
# 3  188.516168  3.685742  ...  4.368332  0.000845  0.008786  0.006791
# 4  180.164683  3.684135  ...  4.371345  0.001067  0.008992  0.007128
#
#         y96       y97       y98       y99      y100      y101
# 0  0.007820  0.007352  0.002554  0.002093  0.002142  0.001900
# ...

# %%
sol.to_csv("Result.txt",index=False,sep=",")

# %% [markdown]
# # This is from the train-test split

# %%
temp = scaler.transform(Data_Predicted_original_domain)

# %%
temp = temp[:,4:]

# %%
Errors_test_data_final = np.zeros(num_features)

# %%
for feature in range(num_features):
    a = test_data_set_y[:,feature]
    b = temp[:,feature]
    Errors_test_data_final[feature] = np.linalg.norm((a-b)/10)

# %%
plt.bar(np.arange(num_features),Errors_test_data_final)
plt.grid()
plt.show()
